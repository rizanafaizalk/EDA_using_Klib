# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv('iris.csv')

# %%
iris.head(5)
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
iris.shape
# Out:
# (149, 5)

# %%
iris.columns
# Out:
# Index(['5.1', '3.5', '1.4', '0.2', 'Iris-setosa'], dtype='object')

# %%
column_names=['sepel length' ,'sepel width','petal length','petal width','species']

# %%
iris.columns=column_names

# %%
iris
# Out:
#      sepel length  sepel width  petal length  petal width         species
# 0             4.9          3.0           1.4          0.2     Iris-setosa
# 1             4.8          2.9           1.3          0.2     Iris-setosa
# 2             4.6          3.1           1.5          0.2     Iris-setosa
# 3             5.0          3.6           1.4          0.2     Iris-setosa
# 4             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.3          2.5           5.0          1.9  Iris-virginica
# 146           6.5          3.0           5.2          2.0  Iris-virginica
# 147           6.2          3.4           5.4          2.3  Iris-virginica
# 148           5.9          3.0           5.1          1.8  Iris-virginica
# 150           4.7          3.2           1.3          0.2     Iris-setosa
#
# [150 rows x 5 columns]

# %%
#iris=iris.rename(columns={'sepel width':'petal length'})

# %%
iris
# Out:
#      sepel length  sepel width  petal length  petal width         species
# 0             4.9          3.0           1.4          0.2     Iris-setosa
# 1             4.8          2.9           1.3          0.2     Iris-setosa
# 2             4.6          3.1           1.5          0.2     Iris-setosa
# 3             5.0          3.6           1.4          0.2     Iris-setosa
# 4             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.3          2.5           5.0          1.9  Iris-virginica
# 146           6.5          3.0           5.2          2.0  Iris-virginica
# 147           6.2          3.4           5.4          2.3  Iris-virginica
# 148           5.9          3.0           5.1          1.8  Iris-virginica
# 150           4.7          3.2           1.3          0.2     Iris-setosa
#
# [150 rows x 5 columns]

# %%
new_row = {'SepelLength':4.7,
        'petal length':3.2,
        'sepel width':1.3, 
        'petal width':0.2,
        'species':'Iris-setosa'
    
}

# %%
iris.loc[150] = new_row

# %%
iris
# Out:
#      sepel length  sepel width  petal length  petal width         species
# 0             4.9          3.0           1.4          0.2     Iris-setosa
# 1             4.8          2.9           1.3          0.2     Iris-setosa
# 2             4.6          3.1           1.5          0.2     Iris-setosa
# 3             5.0          3.6           1.4          0.2     Iris-setosa
# 4             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.3          2.5           5.0          1.9  Iris-virginica
# 146           6.5          3.0           5.2          2.0  Iris-virginica
# 147           6.2          3.4           5.4          2.3  Iris-virginica
# 148           5.9          3.0           5.1          1.8  Iris-virginica
# 150           4.7          3.2           1.3          0.2     Iris-setosa
#
# [150 rows x 5 columns]

# %%
iris.columns
# Out:
# Index(['sepel length', 'sepel width', 'petal length', 'petal width',
#        'species'],
#       dtype='object')

# %%
#count of each species
iris['species'].value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
##it is a balanced data set from the output of havind equal

# %%
#2D SCATTER plot:
#alays understand the axis: labels and scale
iris.plot(kind='scatter',x='sepel length',y='sepel width');
#plt.show()

# %%
sns.set_style("whitegrid");
g = sns.FacetGrid(iris,hue="species", height=4) 
g.map(plt.scatter,"sepel length","sepel width") 
g.add_legend();
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# 3D SCATTER PLOT , can you imagine  d, 5d ,or nd with mathematicals...Ie, BY "PAIR PLOT"

# %%
#  PAIR PLOT        # Ie is he we can make papir as (sepel length and  sepe wifdth), (petel length and petel width) and cam make more pair sl & pW ....

# %%
plt.close();
sns.set_style("whitegrid");
sns.pairplot(iris,hue="species", height=3)
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
